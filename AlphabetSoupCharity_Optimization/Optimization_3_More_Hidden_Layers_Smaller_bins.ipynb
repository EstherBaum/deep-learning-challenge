# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=["EIN", "NAME"])
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`

application_types_to_replace = ["T12", "T2", "T25", "T14", "T29", "T15", "T17"]


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# T13         66
# Other       54
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_vc = application_df['CLASSIFICATION'].value_counts()
print(classification_vc)
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Look at CLASSIFICATION value counts >1
# code from https://stackoverflow.com/questions/22320356/pandas-get-values-from-column-that-appear-more-than-x-times

classification_vc[classification_vc>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = ["C2800","C7100","C1300","C1280","C1230","C1400","C7200","C2300","C1240","C8000",
                              "C7120","C1500","C1800","C6000","C1250","C8200","C1238","C1278","C1235","C1237","C7210","C2400","C1720","C4100","C1257","C1600",
                              "C1260","C2710","C0","C3200","C1234","C1246","C1267","C1256","C1370","C1236","C2190","C4200","C5200","C1248","C2600","C1580","C6100",
                              "C1820","C1900","C2570","C1570", "C3700","C2500","C1283","C2380","C1732","C1728","C2170","C4120", "C8210","C4500","C1245","C2561","C2150"]

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_dummies_df = pd.get_dummies(application_df)
application_dummies_df
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T13  APPLICATION_TYPE_T19  \
# 0                         1                     0                     0
# 1                         0                     0                     0
# 2                         0                     0                     0
# 3                         0                     0                     0
# 4                         0                     0                     0
# ...                     ...                   ...                   ...
# 34294                     0                     0                     0
# 34295                     0                     0                     0
# 34296                     0                     0                     0
# 34297                     0                     0                     0
# 34298                     0                     0                     0
#
#        APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  ...  \
# 0                        0                    0                    0  ...
# 1                        1                    0                    0  ...
# 2                        0                    0                    1  ...
# 3                        1                    0                    0  ...
# 4                        1                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    0                    1                    0  ...
# 34295                    0                    1                    0  ...
# 34296                    1                    0                    0  ...
# 34297                    0                    0                    1  ...
# 34298                    1                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 52 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = application_dummies_df.drop(columns="IS_SUCCESSFUL")
y = application_dummies_df["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=5)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn_model = tf.keras.models.Sequential()

# First hidden layer

nn_model.add(tf.keras.layers.Dense(units=80, activation="relu", input_dim=51))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation="tanh"))

# Third hidden layer
nn_model.add(tf.keras.layers.Dense(units=30, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 80)                4160
#
#  dense_7 (Dense)             (None, 30)                2430
#
#  dense_8 (Dense)             (None, 30)                930
#
#  dense_9 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 7551 (29.50 KB)
# Trainable params: 7551 (29.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model=nn_model.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5638 - accuracy: 0.7230
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5504 - accuracy: 0.7305
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5479 - accuracy: 0.7298
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7331
# Epoch 5/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5448 - accuracy: 0.7336
# Epoch 6/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5441 - accuracy: 0.7341
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7330
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7340
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7354
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5405 - accuracy: 0.7352
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5400 - accuracy: 0.7364
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7359
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7367
# Epoch 14/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5386 - accuracy: 0.7364
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5382 - accuracy: 0.7372
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7360
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7367
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5370 - accuracy: 0.7369
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7367
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5367 - accuracy: 0.7376
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7373
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7381
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5357 - accuracy: 0.7382
# Epoch 24/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5353 - accuracy: 0.7390
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5352 - accuracy: 0.7391
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7382
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7387
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5341 - accuracy: 0.7392
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5342 - accuracy: 0.7392
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5338 - accuracy: 0.7386
# Epoch 31/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5339 - accuracy: 0.7397
# Epoch 32/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5340 - accuracy: 0.7394
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7395
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7394
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5328 - accuracy: 0.7392
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5330 - accuracy: 0.7400
# Epoch 37/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5327 - accuracy: 0.7397
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7399
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5325 - accuracy: 0.7397
# Epoch 40/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7402
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5321 - accuracy: 0.7397
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5323 - accuracy: 0.7395
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5321 - accuracy: 0.7397
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7388
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7400
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7399
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7406
# Epoch 48/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5311 - accuracy: 0.7399
# Epoch 49/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5314 - accuracy: 0.7400
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7401
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7395
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7404
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7396
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7402
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7408
# Epoch 56/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5306 - accuracy: 0.7401
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5309 - accuracy: 0.7407
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7407
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7402
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7404
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7402
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7408
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5298 - accuracy: 0.7408
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7417
# Epoch 65/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5301 - accuracy: 0.7416
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7404
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7416
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5300 - accuracy: 0.7403
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5299 - accuracy: 0.7406
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5300 - accuracy: 0.7409
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5298 - accuracy: 0.7399
# Epoch 72/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5300 - accuracy: 0.7406
# Epoch 73/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5300 - accuracy: 0.7406
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5297 - accuracy: 0.7402
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5292 - accuracy: 0.7406
# Epoch 76/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5299 - accuracy: 0.7406
# Epoch 77/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5296 - accuracy: 0.7409
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5295 - accuracy: 0.7405
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5292 - accuracy: 0.7412
# Epoch 80/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5295 - accuracy: 0.7396
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5294 - accuracy: 0.7410
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5296 - accuracy: 0.7401
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5291 - accuracy: 0.7413
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5294 - accuracy: 0.7405
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5293 - accuracy: 0.7404
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5293 - accuracy: 0.7411
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5297 - accuracy: 0.7402
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5289 - accuracy: 0.7406
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5290 - accuracy: 0.7405
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5288 - accuracy: 0.7412
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5288 - accuracy: 0.7407
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5289 - accuracy: 0.7411
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5289 - accuracy: 0.7405
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5291 - accuracy: 0.7411
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5288 - accuracy: 0.7406
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5286 - accuracy: 0.7409
# Epoch 97/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5286 - accuracy: 0.7410
# Epoch 98/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5289 - accuracy: 0.7414
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5292 - accuracy: 0.7413
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5289 - accuracy: 0.7411

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5653 - accuracy: 0.7287 - 711ms/epoch - 3ms/step
# Loss: 0.5652510523796082, Accuracy: 0.7287463545799255

# %%
# Export our model to HDF5 file
# https://www.tensorflow.org/tutorials/keras/save_and_load#:~:text=To%20save%20weights%20manually%2C%20use,Save%20and%20load%20models%20guide.

nn_model.save('my_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
